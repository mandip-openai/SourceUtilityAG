# %% [markdown]
# <a href="https://colab.research.google.com/github/mandip-openai/SourceUtilityAG/blob/main/Source_Utility_AutoGrader_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Grading with chatberry

# %% [markdown]
# ## Converting the graded data into a dataframe

# %%
import pandas as pd
import json
import blobfile as bf

# Use the local file path
file_path = "az://oairic1/oaibwen/data/source_utility/experiments/ds=20250123/identity=685f9d0e-1b03-442e-b09d-b3339e2a4340/content_enriched_search_result_groups_dump.jsonl"

# Initialize an empty list to collect all the records
records = []

# Read the JSONL file line by line and parse each line as JSON
try:
    with bf.BlobFile(file_path, 'r') as f:
        for i, line in enumerate(f):
            try:
                # Load each line as a JSON object
                record = json.loads(line)
                records.append(record)
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON on line {i + 1}: {e}")
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")

# Print the number of records loaded
print(f"Total records loaded: {len(records)}")

# Convert the list of records to a DataFrame
df = pd.DataFrame(records)

# Display the first few rows of the DataFrame to inspect
print("Initial DataFrame structure:")
print(df.head())

# Function to parse nested JSON strings
def parse_nested_json(json_obj):
    if isinstance(json_obj, str):
        try:
            return json.loads(json_obj)
        except (json.JSONDecodeError, TypeError):
            return json_obj
    return json_obj

# Apply parsing to the 'document' and 'query' columns if they are in string format
if 'document' in df.columns:
    df['document'] = df['document'].apply(parse_nested_json)
if 'query' in df.columns:
    df['query'] = df['query'].apply(parse_nested_json)

# Further flatten the nested dictionaries if needed
document_df = pd.json_normalize(df['document']) if 'document' in df.columns else pd.DataFrame()
query_df = pd.json_normalize(df['query']) if 'query' in df.columns else pd.DataFrame()

# Combine the DataFrame with the parsed 'document' and 'query' columns
if not document_df.empty:
    df = pd.concat([df.drop(columns=['document']), document_df], axis=1)
if not query_df.empty:
    df = pd.concat([df.drop(columns=['query']), query_df], axis=1)

# Display the first few rows of the consolidated DataFrame
print("Consolidated DataFrame structure:")
print(df.head())
# Out:
# Total records loaded: 30
# Initial DataFrame structure:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {"document":{"url":"https://apps.apple.com/us/app/google-translate/id414706506","title":"‎Google Translate on the App Store","content":"## What’s New\n\nDec 11, 2024\n\nVersion 8.23.536\n\n• Several bug fixes and usability improvements\n\n## Ratings and Reviews\n\n4.3 out of 5\n\nathilus , 01/16/2022\n\n### Longtime User\n\n> I’ve used this app for many years across many devices. It’s had many wonderful improvements over the years. However, since the update giving masculine/feminine translations for gendered languages, copy & paste has been ruined for me.\n> Previously, the app would often predict needed gendered letters/words based on other words being translated, and a simple copy & paste almost always the immediately available next step, it now copies both gendered translations, which can’t be pasted into certain fields that have limited characters (Twitter, TikTok, for example). This has become a point of major annoyance, and I find myself often using other translators. I enjoy THIS translator, and have a sense of loyalty to it, despite the absurdity of that, and would love to see copy & paste work only with the gendered translation provided, also excluding the “masculine” and “feminine” indicators, which also gets copied.\n\nMTLima1995 , 02/24/2022\n\n### Horrible Application Given the Size of the Company\n\n> The Google translate app is a joke. There are very few apps that can lead someone to yell expletives while sitting in their kitchen trying to enjoy a cup of tea. Editing something you’ve written on the Google Translate App is a pitiful process filled with tapping the screen of your phone over and over attempting to unselect individual words or sentences. Sometimes it selects the entirety of what you’ve written and won’t allow you to unselect it without a fight. It’s unconscionable tha ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {"document":{"url":"https://apps.apple.com/us/app/google-translate/id414706506","title":"‎Google Translate on the App Store","content":"## App Privacy\n\nThe developer, Google, indicated that the app’s privacy practices may include handling of data as described below. For more information, see the 【4†developer’s privacy policy†policies.google.com】.\n\n### Data Linked to You\n\ ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {"document":{"url":"https://apps.apple.com/us/app/google-translate/id414706506","title":"‎Google Translate on the App Store","content":"  * 【0†Apple†www.apple.com】\n\n【1†App Store†www.apple.com】 Preview\n\n## Screenshots\n\n  * 【2†iPhone】\n  * 【3†iPad】\n\nTranslate between up to 249 languages. Feature support varies by language:\n• Text: Translate between languages by typing\n• Offline: Translate with no internet connection\n• Instant camera translation: Translate text in images instantly by just pointing your camera\n• Photos: Translate text in taken or imported photos\n• Dictation: Translate spoken words and phrases\n• Conversations: Translate bilingual conversations on the fly\n• Transcribe: Continuously translate someone speaking a different language in near real-time\n• Handwriting: Draw text characters instead of typing\n• Phrasebook: Star and save translated words and phrases for future reference\nPermissions notice:\n• Microphone for speech translation\n• Camera for translating text via the camera\n• Photos for importing photos from your library\nTranslations between the following languages are supported:\nAbkhaz, Acehnese, Acholi, Afar, Afrikaans, Albanian, Alur, Amharic, Arabic, Armenian, Assamese, Avar, Awadhi, Aymara, Azerb ...
# 3  {"document":{"url":"https://apps.apple.com/td/app/google-translate/id414706506","title":"‎Google Translate on the App Store","content":"  * 【0†Apple†www.apple.com】\n\n【1†App Store†www.apple.com】 Preview\n\n## Screenshots\n\n  * 【2†iPhone】\n  * 【3†iPad】\n\nTranslate between up to 249 languages. Feature support varies by language:\n• Text: Translate between languages by typing\n• Offline: Translate with no Internet connection\n• Instant camera translation: Translate text in images instantly by just pointing your camera\n• Photos: Translate text in taken or imported photos\n• Dictation: Translate spoken words and phrases\n• Conversations: Translate bilingual conversations on the fly\n• Transcribe: Continuously translate someone speaking a different language in near real-time\n• Handwriting: Draw text characters instead of typing\n• Phrasebook: Star and save translated words and phrases for future reference\nPermissions notice:\n• Microphone for speech translation\n• Camera for translating text via the camera\n• Photos for importing photos from your library\nTranslations between the following languages are supported:\nAbkhaz, Acehnese, Acholi, Afar, Afrikaans, Albanian, Alur, Amharic, Arabic, Armenian, Assamese, Avar, Awadhi, Aymara, Azerbaijani, Balinese, Baluchi, Bambara, Baoulé, Bashkir, Basque, Batak Karo, Batak Simalungun, Batak Toba, Belarusian, Bemba, Bengali, Betawi, Bhojpuri, Bikol, Bosnian, Breton, Bulgarian, Buryat, Cantonese, Catalan, Cebuano, Chamorro, Chechen, Chichewa, Chinese (Simplified), Chinese (Traditional), Chuukese, Chuvash, Corsican, Crimean Tatar, Croatian, Czech, Danish, Dari, Dhivehi, Dinka, Dogri, Dombe, Dutch, Dyula, Dzongkha, English, Esperanto, Estonian, Ewe, Faroese, Fijian, Filipino, Finnish, Fon, French, Frisian, Friulian, Fulani, Ga, Galician, Georgian, German, Greek, Guarani, Gujarati, Haitian Creole, Hakha Chin, Hausa, Hawaiian, Hebrew, Hiligaynon, Hindi, Hmong, Hungarian, Hunsrik, Iban, Icelandic, Igbo, Ilocano, Indonesian, Irish Gaelic, Italian, Jamaican Patois, Japanese, Javanese, Jingpo, Kalaallisut, Kannada, Kanuri, Kapampangan, Kazakh, Khasi, Khmer, Kiga, Kikongo, Kinyarwanda, Kituba, Kokborok, Komi, Konkani, Korean, Krio, Kurdish (Kurmanji), Kurdish (Sorani), Kyrgyz, Lao, Latgalian, Latin, Latvian, Ligurian, Limburgish, Lingala, Lithuanian, Lombard, Luganda, Luo, Luxembourgish, Macedonian, Madurese, Maithili, Makassar, Malagasy, Malay, Malay (Jawi), Malayalam, Maltese, Mam, Manx, Maori, Marathi, Marshallese, Marwadi, Mauritian Creole, Meadow Mari, Meiteilon (Manipuri), Minang, Mizo, Mongolian, Myanmar (Burmese), N'Ko, Nahuatl (Eastern Huasteca), Ndau, Ndebele (South), Nepal Bhasa (Newari), Nepali, Norwegian, Nuer, Occitan, Odia (Oriya), Oromo, Ossetian, Pangasinan, Papiamento, Pashto, Persian, Polish, Portuguese (Brazil), Portuguese (Portugal), Punjabi (Gurmukhi), Punjabi (Shahmukhi), Quechua, Qʼeqchiʼ, Romani, Romanian, Rundi, Russian, Sami (North), Samoan, Sango, Sanskrit, Santali, Scots Gaelic, Sepedi, Serbian, Sesotho, Seychellois Creole, Shan, Shona, Sicilian, Silesian, Sindhi, Sinhala, Slovak, Slovenian, Somali, Spanish, Sundanese, Susu, Swahili, Swati, Swedish, Tahitian, Tajik, Tamazight, Tamazight (Tifinagh), Tamil, Tatar, Telugu, Tetum, Thai, Tibetan, Tigrinya, Tiv, Tok Pisin, Tongan, Tsonga, Tswana, Tulu, Tumbuka, Turkish, Turkmen, Tuvan, Twi, Udmurt, Ukrainian, Urdu, Uyghur, Uzbek, Venda, Venetian, Vietnamese, Waray, Welsh, Wolof, Xhosa, Yakut, Yiddish, Yoruba, Yucatec Maya, Zapotec, Zulu\n\n## What’s New\n\n11 Dec 2024\n\nVersion 8.23.536\n\n• Several bug fixes and usability improvements\n\n## Ratings and Reviews\n\n4.6 out of 5\n\n## App Privacy\n\nThe developer, Google, indicated that the app’s privacy practices may include handling of data as described below. For more information, see the 【4†developer’s privacy policy†policies.google.com】.\n\n### Data Linked to You\n\nThe following data may be collected and linked to your identity:\n\n  * Location\n  * Contact Info\n  *  ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {"document":{"url":"https://apps.apple.com/us/app/google-translate/id414706506?platform=ipad","title":"‎Google Translate on the App Store","content":"## What’s New\n\nOct 2, 2024\n\nVersion 8.18.580\n\n• Several bug fixes and usability improvements\n\n## Ratings and Reviews\n\n4.3 out of 5\n\ngrubu413 , 11/16/2023\n\n### Now 5 Stars But Still Recommed Deepl\n\n> This is 1 of only 2 translator apps I will give 5 stars. It has gotten much better over time to the point that I can reasonable rely on it to doble check things. If you need real time transcription, Google Translate is the best. For anything else though including accuracy, definitely use Deepl. Google Translate has come a long way at figuring out Idioms, sayings, the right usage when something is ambiguous, etc. However, Deepl still gets things right more often, especially with the paid version when it can deep dive into things like verification of tone and level of formality for audience where what you have on paper may be 100% correct but may the verb usage is informal but a student is talking to a teacher. This is area Google Translate comes up short. Overall though, 5 stars and definitely far better than any of those other translator apps out there except Deepl.\n\nMTLima1995 , 02/24/2022\n\n### Horrible Application Given the Size of the Company\n\n> The Google translate app is a joke. There are very few apps that can lead someone to yell expletives while sitting in their kitchen trying to enjoy a cup of tea. Editing something you’ve written on the Google Translate App is a pitiful process filled with tapping the screen of your phone over and over attempting to unselect individual words or sentences. Sometimes it selects the entirety of what you’ve written and won’t allow you to unselect it without a fight. It’s unconscionable tha ...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ## Relevance Evaluation\n* rating: 7\n* justification: The query "google translate" suggests that the user is seeking information about the Google Translate service or application. The document is the App Store page for Google Translate, providing direct access to download the app, view its features, updates, and user reviews. The content is highly specific to the query intent, directly matching the user's likely need to find or download the Google Translate app. The information is current and contextually appropriate for a user located in the US seeking the iOS version of the app.\n* notes: None.\n\n## Timeliness Evaluation\n* rating: 7\n* justification: The document reflects the most recent update to the Google Translate app as of December 11, 2024, which is less than a month prior to the query date of January 7, 2025. This indicates that the application is being actively maintained with recent bug fixes and improvements. Although the user reviews showcased are from early 2022, it's reasonable to assume that the App Store page also includes more recent reviews; the presented selection may be a subset. Overall, the content is current and up-to-date, aligning with user expectations for timeliness.\n* notes: The outdated user reviews included in the content may not reflect the most current user experiences with the app.\n\n## Navigational or Transactional\n* rating: 7\n* justification: The query "google translate" suggests a navigational intent to reach the official Google Translate application, or a transactional intent to download or access the service. The search result directly leads to the App Store page for the Google Translate app, enabling the user to download the application immediately. This fulfills both navigational and transactional intents at the highest level by providing direct access to the official app's page without additional steps.\n* notes: None.\n\n## Geographic & Cultural Relevance\n* rating: 7\n* justification: The document is the US App Store page for the Google Translate app, perfectly aligning with the user's location in Seattle, Washington, USA. This ensures that the content is culturally appropriate, and any region-specific information, such as language support and functionalities, is relevant to a US audience. The App Store is a trusted, authoritative source for app distribution in this region, enhancing its local authority.\n* notes: None.\n\n## Accuracy Evaluation\n* rating: 7\n* justification: The document is sourced directly from the official Apple App Store, providing verifiable and accurate information about the Google Translate app, including version updates and user reviews. The details such as the "What's New" section accurately reflect the app's latest updates, and the user reviews are presented authentically, reflecting genuine user experiences. There is no evidence of misinformation or omission of critical information.\n* notes: None.\n\n## High Stakes\n* rating: Not High Stake\n* justification: The document is an App Store page for the Google Translate application, primarily intended for users to download and obtain information about the app. While the translation tool could be used in contexts  ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ## Relevance\n* rating: 7\n* justification: The query "google translate" likely reflects an informational intent, where the user seeks information about Google Translate, possibly to use the service, download the app, or access features. The document is a page on the Apple App Store for the Google Translate app, providing details about the app, its features, compatibility, and privacy information. This directly matches the user's intent, offering a download source for the app, matching both the general term "google translate" and providing a direct path to access it on iOS. Hence, the content is highly specific and directly aligns with the query's intent, providing focused, relevant information.\n* notes: None.\n\n## Timeliness\n* rating: 6\n* justification: The document is an App Store page for the Google Translate app, including details like compatibility with iOS 16.0 or later. While the publication date is not specified, App Store pages are regularly updated to reflect the current version of the app. Given the query date is January 7, 2025, and considering that app details on official platforms are maintained to ensure accuracy, the provided information is likely to be up to date. However, without explicit confirmation of a recent update, a rating of 6 reflects high timeliness with a slight reservation due to the absence of a clear publication date.\n* notes: Including specific publication or last updated dates would improve clarity on the timeliness of the content.\n\n## Navigational or Transactional\n* rating: 7\n* justification: The query "google translate" could be interpreted as the user seeking to navigate to the Google Translate app or obtain the app for use. The document is the App Store page for Google Translate, allowing the user to directly download the app. This directly matches transactional intent, enabling the user to complete the intended action efficiently. It also serves navigational intent by directing the user to the specific app page. Therefore, the result clearly meets both navigational and transactional intents, offering direct value and fulfilling user needs.\n* notes: None.\n\n## Geographic & Cultural Relevance\n* rating: 7\n* justification: The user is located in Seattle, Washington, USA, and the document URL is 'https://apps.apple.com/us/app/google-translate/id414706506', indicating the US version of the App Store. The information provided, such as supported languages, compatibility, and privacy policies, is relevant to a US-based user. Therefore, the content is geographically and culturally appropriate, aligning perfectly with the user's regional context.\n* notes: None.\n\n## Accuracy\n* rating: 7\n* justification: The information presented is from the official Apple App Store, detailing the Google Translate app. This includes standard data such as app privacy practices, compatibility requirements, size, and category. Given that the content originates from a reputable source, it is expected to be accurate and well-maintained, providing users with reliable information. There are no indications of misinformation or inaccuracies in the provided content.\n* notes: None.\n\n## High Stakes ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ## Relevance\n* rating: 6\n* justification: The user's query is "google translate," which likely indicates an intent to access or find information about Google Translate. The provided document is a page from the Apple App Store for the Google Translate app, including details about its features and supported languages. This result directly addresses the query, offering specific and detailed information about the Google Translate app, including how to download it. It aligns with the user's context, particularly if they are using an Apple device, such as an iPhone or iPad. Therefore, the result is highly relevant, though it might be slightly less so if the user is on a non-Apple device.\n* notes: The relevance could be even higher if the user's device type were specified (e.g., iOS device user), confirming the applicability of the App Store link.\n\n## Timeliness\n* rating: 4\n* justification: The document provides information about the Google Translate app, including its features and supported languages. However, the publication date is not specified (N/A), making it unclear whether the details are up-to-date as of the query date (January 7, 2025). Given that app features and supported languages can change over time, there is a possibility that the information may be outdated, potentially missing recent updates or new features. Therefore, while the content remains generally relevant, the lack of a clear publication date diminishes its timeliness.\n* notes: Including a publication or last updated date would improve the assessment of timeliness.\n\n## Navigational or Transactional\n* rating: 6\n* justification: The user's query "google translate" suggests a possible navigational intent to access Google's translation service or a transactional intent to download the Google Translate app. The document links to the Apple App Store page for the Google Translate app, enabling users to download the app directly. Therefore, it effectively fulfills the transactional intent for users seeking to install the app on an Apple device. However, for users intending to navigate to the Google Translate website for immediate use without installation, this result may be less directly helpful.\n* notes: The rating assumes the user may be interested in downloading the app; if their intent is solely web-based translation, this might not fully meet their needs.\n\n## Geographic & Cultural Relevance\n* rating: 7\n* justification: The document is from the US version of the Apple Ap ...
# 3                                                                         ## Relevance\n* rating: 7\n* justification: The query "google translate" indicates that the user is seeking information about Google Translate, possibly aiming to download or learn more about the application. The provided document is a detailed App Store page for the Google Translate app, including descriptions, features, supported languages, and download links. This content is highly specific to the app and directly matches the user's intent. Being the official app page, it perfectly aligns with the user's potential needs and expectations.\n* notes: None\n\n## Timeliness\n* rating: 6\n* justification: The Google Translate app was last updated on December 11, 2024, less than a month prior to the current date of January 7, 2025. For an app that's likely to be in continuous development, this recent update indicates active maintenance and improvements. While the "What's New" section mentions "bug fixes and usability improvements," the specific nature of these updates isn't detailed. Nonetheless, the recency suggests the app is kept up-to-date, which is important for functionality and security.\n* notes: None\n\n## Navigational or Transactional\n* rating: Highest\n* justification: The user searching for "google translate" is likely seeking to access, download, or get information about the Google Translate service or app. This result leads directly to the official App Store page for the Google Translate app, enabling the user to download it immediately. Therefore, it meets the transactional intent efficiently, providing a direct and valuable path to acquire the app without unnecessary steps.\n* notes: None\n\n## Geographic & Cultural Relevance\n* rating: High\n* justification: The content is tailored to the US market, with pricing, language, and app compatibility information appropriate for users in the United States. The App Store page is localized for the US audience, ensuring cultural and geographic alignment with the user's context in Seattle, Washington. This localization enhances the user experience by providing region-specific details and support.\n* notes: None\n\n## Accuracy\n* rating: 7\n* justification: The information is sourced from the official Apple App Store, detailing Google's app. It includes specific features, supported languages, privacy policies, and version updates. Given that it's from authoritative sources and contains detailed, verifiable information, the content can be considered highly accurate. There's no indication of misinformation or incomplete details.\n* notes: None\n\n## High Stakes\n* rating: Not High Stake\n* justification: The content is an App Store page for a language translation application. While effective language translation can aid in communication, the page itself does not directly impact a person's health, financial stability, safety, or well-being in a significant manner as defined by High Stakes categories. It doesn't fall under critical areas like medical advice, legal information, or financial guidance.\n* notes: None\n\n## Harmful\n* rating: Not Harmful\n* justification: The content describes the features and details of the Google Translate app on the Apple App Store. It does not promote misinformation, self-harm, violence, illegal activities, or exploitation. There are no elements that could be considered harmful to individuals or society. The information is straightforward, informative, and safe for general audiences.\n* notes: None\n\n## Explicit content\n* rating: Not Porn\n* justification: The content is an App Store page providing details about the Google Translate application, including features, supported languages, and privacy information. There is no sexually explicit or suggestive material, imagery, or links present. The content is appropriate for all audiences and doesn’t contain adult themes.\n* notes: None\n\n## Spam\n* rating: Not Spam\n* justification: The content is an official Apple App Stor ...
# ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          * 【0†Apple†www.apple.com】\n\n【1†App Store†www.apple.com】 Preview\n\n## Screenshots\n\n  * 【2†iPhone】\n  * 【3†iPad】\n\nTranslate between up to 249 languages. Feature support varies by language:\n• Text: Translate between languages by typing\n• Offline: Translate with no internet connection\n• Instant camera translation: Translate text in images instantly by just pointing your camera\n• Photos: Translate text in taken or imported photos\n• Dictation: Translate spoken words and phrases\n• Conversations: Translate bilingual conversations on the fly\n• Transcribe: Continuously translate someone speaking a different language in near real-time\n• Handwriting: Draw text characters instead of typing\n• Phrasebook: Star and save translated words and phrases for future reference\nPermissions notice:\n• Microphone for speech translation\n• Camera for translating text via the camera\n• Photos for importing photos from your library\nTranslations between the following languages are supported:\nAbkhaz, Acehnese, Acholi, Afar, Afrikaans, Albanian, Alur, Amharic, Arabic, Armenian, Assamese, Avar, Awadhi, Aymara, Azerbaijani, Balinese, Baluchi, Bambara, Baoulé, Bashkir, Basque, Batak Karo, Batak Simalungun, Batak Toba, Belarusian, Bemba, Bengali, Betaw ...
, Scots Gaelic, Sepedi, Serbian, Sesotho, Seychellois Creole, Shan, Shona, Sicilian, Silesian, Sindhi, Sinhala, Slovak, Slovenian, Somali, Spanish, Sundanese, Susu, Swahili, Swati, Swedish, Tahitian, Tajik, Tamazight, Tamazight (Tifinagh), Tamil, Tatar, Telugu, Tetum, Thai, Tibetan, Tigrinya, Tiv, Tok Pisin, Tongan, Tsonga, Tswana, Tulu, Tumbuka, Turkish, Turkmen, Tuvan, Twi, Udmurt, Ukrainian, Urdu, Uyghur, Uzbek, Venda, Venetian, Vietnamese, Waray, Welsh, Wolof, Xhosa, Yakut, Yiddish, Yoruba, Yucatec Maya, Zapotec, Zulu\n\n## What’s New\n\n11 Dec 2024\n\nVersion 8.23.536\n\n• Several bug fixes and usability improvements\n\n## Ratings and Reviews\n\n4.6 out of 5\n\n## App Privacy\n\nThe developer, Google, indicated that the app’s privacy practices may include handling of data as described below. For more information, see the 【4†developer’s privacy policy†policies.google.com】.\n\n### Data Linked to You\n\nThe following data may be collected and linked to your identity:\n\n  * Location\n  * Contact Info\n  * Contacts\n  * User Content\n  * Search History\n  * Identifiers\n  * Usage Data\n  * Diagnostics\n  * Other Data\n\n### Data Not Linked  ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ## What’s New\n\nOct 2, 2024\n\nVersion 8.18.580\n\n• Several bug fixes and usability improvements\n\n## Ratings and Reviews\n\n4.3 out of 5\n\ngrubu413 , 11/16/2023\n\n### Now 5 Stars But Still Recommed Deepl\n\n> This is 1 of only 2 translator apps I will give 5 stars. It has gotten much better over time to the point that I can reasonable rely on it to doble check things. If you need real time transcription, Google Translate is the best. For anything else though including accuracy, definitely use Deepl. Google Translate has come a long way at figuring out Idioms, sayings, the right usage when something is ambiguous, etc. However, Deepl still gets things right more often, especially with the paid version when it can deep dive into things like verification of tone and level of formality for audience where what you have on paper may be 100% correct but may the verb usage is informal but a student is talking to a teacher. This is area Google Translate comes up short. Overall though, 5 stars and definitely far better than any of those other translator apps out there except Deepl.\n\nMTLima1995 , 02/24/2022\n\n### Horrible Application Given the Size of the Company\n\n> The Google translate app is a joke. There are very few apps that can lead someone to yell expletives while sitting in their kitchen trying to enjoy a cup of tea. Editing something you’ve written on the Google Translate App is a pitiful process filled with tapping the screen of your phone over and over attempting to unselect individual words or sentences. Sometimes it selects the entirety of what you’ve written and won’t allow you to unselect it without a fight. It’s unconscionable that the process for editing what you’ve written doesn’t follow every other smart phone format. Not only that, when you’ve finished writing ...
#
#   document.pub_date             query                  create_timestamp  \
# 0              None  google translate  2025-01-07T14:53:23.333252-08:00
# 1              None  google translate  2025-01-07T14:53:23.333252-08:00
# 2              None  google translate  2025-01-07T14:53:23.333252-08:00
# 3              None  google translate  2025-01-07T14:53:23.333252-08:00
# 4              None  google translate  2025-01-07T14:53:23.333252-08:00
#
#   orig_query user_metadata.time_zone  ... user_metadata.cf_connecting_ip  \
# 0       None                    None  ...                           None
# 1       None                    None  ...                           None
# 2       None                    None  ...                           None
# 3       None                    None  ...                           None
# 4       None                    None  ...                           None
#
#   user_metadata.user_country user_metadata.user_region  \
# 0                         US                Washington
# 1                         US                Washington
# 2                         US                Washington
# 3                         US                Washington
# 4                         US                Washington
#
#   user_metadata.user_region_code user_metadata.ip_city user_metadata.latitude  \
# 0                           None               Seattle                   None
# 1                           None               Seattle                   None
# 2                           None               Seattle                   None
# 3                           None               Seattle                   None
# 4                           None               Seattle                   None
#
#   user_metadata.longitude user_metadata.locationAccuracy  \
# 0                    None                           None
# 1                    None                           None
# 2                    None                           None
# 3                    None                           None
# 4                    None                           None
#
#   user_metadata.is_precise_location user_metadata.plan_type
# 0                              None                    None
# 1                              None                    None
# 2                              None                    None
# 3                              None                    None
# 4                              None                    None
#
# [5 rows x 21 columns]

# %%
pd.set_option('display.max_colwidth', None)
df.grading[2]
# Out:
# '## Relevance\n* rating: 6\n* justification: The user\'s query is "google translate," which likely indicates an intent to access or find information about Google Translate. The provided document is a page from the Apple App Store for the Google Translate app, including details about its features and supported languages. This result directly addresses the query, offering specific and detailed information about the Google Translate app, including how to download it. It aligns with the user\'s context, particularly if they are using an Apple device, such as an iPhone or iPad. Therefore, the result is highly relevant, though it might be slightly less so if the user is on a non-Apple device.\n* notes: The relevance could be even higher if the user\'s device type were specified (e.g., iOS device user), confirming the applicability of the App Store link.\n\n## Timeliness\n* rating: 4\n* justification: The document provides information about the Google Translate app, including its features and supported languages. However, the publication date is not specified (N/A), making it unclear whether the details are up-to-date as of the query date (January 7, 2025). Given that app features and supported languages can change over time, there is a possibility that the information may be outdated, potentially missing recent updates or new features. Therefore, while the content remains generally relevant, the lack of a clear publication date diminishes its timeliness.\n* notes: Including a publication or last updated date would improve the assessment of timeliness.\n\n## Navigational or Transactional\n* rating: 6\n* justification: The user\'s query "google translate" suggests a possible navigational intent to access Google\'s translation service or a transactional intent to download the Google Translate app. The document links to the Apple App Store page for the Google Translate app, enabling users to download the app directly. Therefore, it effectively fulfills the transactional intent for users seeking to install the app on an Apple device. However, for users intending to navigate to the Google Translate website for immediate use without installation, this result may be less directly helpful.\n* notes: The rating assumes the user may be interested in downloading the app; if their intent is solely web-based translation, this might not fully meet their needs.\n\n## Geographic & Cultural Relevance\n* rating: 7\n* justification: The document is from the US version of the Apple App Store and is presented in English, aligning perfectly with the user\'s location in Seattle, USA, and likely cultural context. The content is tailored for users in the United States, ensuring that the application details, availability, and download process are relevant and applicable. Therefore, the document demonstrates high geographic and cultural relevance to the user.\n* notes:\n\n## Accuracy\n* rating: 7\n* justification: The document is sourced from the official Apple App Store, providing authoritative and accurate information about the Google Translate app. It outlines the app\'s features, permissions, and supported languages accurately, as expected from an official app listing. There is no indication of misinformation, omission, or distortion of information. Therefore, the content is considered fully accurate and reliable.\n* notes:\n\n## High Stakes\n* rating: Not High Stake\n* justification: The content is an App Store listing for the Google Translate app, which is a tool for language translation. It does not directly involve areas that can significantly impact a person\'s health, financial stability, safety, or well-being as defined in High Stakes categories like medical advice, financial transactions, or legal information. Therefore, this page does not qualify as a High Stake page.\n* notes:\n\n## Harmful\n* rating: Not Harmful (7)\n* justification: The content is an official listing for the Google Translate app on the Apple App Store, providing information abo ...

# %%
# Function to parse a single section

import pandas as pd
import re

def parse_section(section):
    lines = section.strip().split('\n')
    category = lines[0].replace('## ', '').strip()
    rating_line = next((line for line in lines if line.startswith('* rating:')), None)
    justification_line = next((line for line in lines if line.startswith('* justification:')), None)
    notes_line = next((line for line in lines if line.startswith('* notes:')), None)

    rating = rating_line.replace('* rating:', '').strip() if rating_line else None
    justification = justification_line.replace('* justification:', '').strip() if justification_line else None
    notes = notes_line.replace('* notes:', '').strip() if notes_line else None

    return {
        'category': category,
        'rating': rating,
        'justification': justification,
        'notes': notes
    }

# Function to process the 'grading' column
def process_grading_column(grading_text):
    # Split the grading text into sections
    sections = re.split(r'\n## ', grading_text)
    parsed_data = [parse_section(section) for section in sections if section.strip()]

    # Convert parsed data to DataFrame
    grading_df = pd.DataFrame(parsed_data)
    return grading_df

# Apply the function to each row in the 'grading' column and concatenate the results

flattened_dfs = df['grading'].apply(process_grading_column)

# Concatenate the list of DataFrames into a single DataFrame
flattened_df = pd.concat(flattened_dfs.tolist(), ignore_index=True)

# Display the flattened DataFrame
flattened_df.head(15)
# Out:
#                            category          rating  \
# 0              Relevance Evaluation               7
# 1             Timeliness Evaluation               7
# 2     Navigational or Transactional               7
# 3   Geographic & Cultural Relevance               7
# 4               Accuracy Evaluation               7
# 5                       High Stakes  Not High Stake
# 6                           Harmful     Not Harmful
# 7                  Explicit Content        Not Porn
# 8                              Spam        Not Spam
# 9                    Source Quality            High
# 10            Diversity or Coverage               6
# 11       User Experience Evaluation               7
# 12                        Relevance               7
# 13                       Timeliness               6
# 14    Navigational or Transactional               7
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            justification  \
# 0                                                                                                                                  The query "google translate" suggests that the user is seeking information about the Google Translate service or application. The document is the App Store page for Google Translate, providing direct access to download the app, view its features, updates, and user reviews. The content is highly specific to the query intent, directly matching the user's likely need to find or download the Google Translate app. The information is current and contextually appropriate for a user located in the US seeking the iOS version of the app.
# 1                                                                                                               The document reflects the most recent update to the Google Translate app as of December 11, 2024, which is less than a month prior to the query date of January 7, 2025. This indicates that the application is being actively maintained with recent bug fixes and improvements. Although the user reviews showcased are from early 2022, it's reasonable to assume that the App Store page also includes more recent reviews; the presented selection may be a subset. Overall, the content is current and up-to-date, aligning with user expectations for timeliness.
# 2                                                                                                                                                                                            The query "google translate" suggests a navigational intent to reach the official Google Translate application, or a transactional intent to download or access the service. The search result directly leads to the App Store page for the Google Translate app, enabling the user to download the application immediately. This fulfills both navigational and transactional intents at the highest level by providing direct access to the official app's page without additional steps.
# 3                                                                                                                                                                                                                                            The document is the US App Store page for the Google Translate app, perfectly aligning with the user's location in Seattle, Washington, USA. This ensures that the content is culturally appropriate, and any region-specific information, such as language support and functionalities, is relevant to a US audience. The App Store is a trusted, authoritative source for app distribution in this region, enhancing its local authority.
# 4                                                                                                                                                                                                                             The document is sourced directly from the official Apple App Store, providing verifiable and accurate information about the Google Translate app, including version updates and user reviews. The details such as the "What's New" section accurately reflect the app's latest updates, and the user reviews are presented authentically, reflecting genuine user experiences. There is no evidence of misinformation or omission of critical information.
# 5                                                                                                                                                                                            The document is an App Store page for the Google Translate application, primarily intended for users to download and obtain information about the app. While the translation tool could be used in contexts impacting health, legal matters, or safety, this webpage itself does not provide direct information or services in those High Stake categories. Therefore, the page does not qualify as a High Stake page in terms of content that significantly impacts a person's well-being.
# 6                                                                                                                                                                                                                                                                         The document is an official App Store page for the Google Translate application, providing legitimate information about the app, its updates, and user reviews. There is no indication of harmful misinformation, promotion of self-harm, violence, illegal activities, or deceptive practices. The content is standard for an app distribution platform and poses no apparent risk to individuals or society.
# 7                                                                                                                                                                                                                                                                                                                                                                                                             The content presented is an official App Store page for the Google Translate application and does not contain any sexually explicit or suggestive materials. It focuses on app information, updates, and user reviews, all of which are appropriate for general audiences.
# 8                                                                                                                                                                                                                                                                                                                                                                The document is an official page on Apple's App Store, a legitimate and trusted platform for app distribution. There is no evidence of spam practices such as cloaking, keyword stuffing, link spam, or deceptive practices. The content is transparent, user-oriented, and adheres to standard web quality guidelines.
# 9
# 10                                                                                                       The document thoroughly covers the Google Translate application as available on the App Store, providing detailed information about the app’s version history, updates, and user reviews. For users seeking to learn about or download the mobile app, the coverage is comprehensive. However, it does not encompass broader information about Google Translate as a service, such as its web interface or integration with other platforms. Therefore, while the coverage is extensive concerning the iOS application, it lacks information about other facets of the service.
# 11                                                                                                                                               The App Store page for Google Translate is designed with user experience in mind, exhibiting a clean layout with clear headings, concise descriptions, and user-friendly navigation. Information such as the "What's New" section and user reviews are well-organized and easily accessible. The design is responsive, and the page is optimized for both desktop and mobile devices. The App Store's consistent interface ensures users can quickly understand and engage with the content, facilitating an excellent user experience.
# 12  The query "google translate" likely reflects an informational intent, where the user seeks information about Google Translate, possibly to use the service, download the app, or access features. The document is a page on the Apple App Store for the Google Translate app, providing details about the app, its features, compatibility, and privacy information. This directly matches the user's intent, offering a download source for the app, matching both the general term "google translate" and providing a direct path to access it on iOS. Hence, the content is highly specific and directly aligns with the query's intent, providing focused, relevant information.
# 13                                                        The document is an App Store page for the Google Translate app, including details like compatibility with iOS 16.0 or later. While the publication date is not specified, App Store pages are regularly updated to reflect the current version of the app. Given the query date is January 7, 2025, and considering that app details on official platforms are maintained to ensure accuracy, the provided information is likely to be up to date. However, without explicit confirmation of a recent update, a rating of 6 reflects high timeliness with a slight reservation due to the absence of a clear publication date.
# 14                                                                                                     The query "google translate" could be interpreted as the user seeking to navigate to the Google Translate app or obtain the app for use. The document is the App Store page for Google Translate, allowing the user to directly download the app. This directly matches transactional intent, enabling the user to complete the intended action efficiently. It also serves navigational intent by directing the user to the specific app page. Therefore, the result clearly meets both navigational and transactional intents, offering direct value and fulfilling user needs.
#
#                                                                                                                                                               notes
# 0                                                                                                                                                             None.
# 1                                                 The outdated user reviews included in the content may not reflect the most current user experiences with the app.
# 2                                                                                                                                                             None.
# 3                                                                                                                                                             None.
# 4                                                                                                                                                             None.
# 5                                                                                                                                                             None.
# 6                                                                                                                                                             None.
# 7                                                                                                                                                             None.
# 8                                                                                                                                                             None.
# 9                                                                                                                                                             None.
# 10  The scope of the content is appropriately focused on the app, but users seeking more general information about Google Translate may require additional sources.
# 11                                                                                                                                                            None.
# 12                                                                                                                                                            None.
# 13                                                     Including specific publication or last updated dates would improve clarity on the timeliness of the content.
# 14                                                                                                                                                            None.

# %%
import pandas as pd
import json
import blobfile as bf

# Use the local file path
file_path = "/tmp/dump_feather_results/graded_search_result_groups_dump_Rel_SamplewC.jsonl"

# Initialize an empty list to collect all the records
records = []

# Read the JSONL file line by line and parse each line as JSON
try:
    with open(file_path, 'r') as f:
        for i, line in enumerate(f):
            try:
                # Load each line as a JSON object
                record = json.loads(line)
                records.append(record)
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON on line {i + 1}: {e}")
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")

# Print the number of records loaded
print(f"Total records loaded: {len(records)}")

# Convert the list of records to a DataFrame
df = pd.DataFrame(records)

# Function to parse nested JSON strings
def parse_nested_json(json_obj):
    if isinstance(json_obj, str):
        try:
            return json.loads(json_obj)
        except (json.JSONDecodeError, TypeError):
            return json_obj
    return json_obj

# Apply parsing to the 'document' and 'query' columns if they are in string format
if 'document' in df.columns:
    df['document'] = df['document'].apply(parse_nested_json)
if 'query' in df.columns:
    df['query'] = df['query'].apply(parse_nested_json)

# Further flatten the nested dictionaries if needed
document_df = pd.json_normalize(df['document']) if 'document' in df.columns else pd.DataFrame()
query_df = pd.json_normalize(df['query']) if 'query' in df.columns else pd.DataFrame()

# Combine the DataFrame with the parsed 'document' and 'query' columns
if not document_df.empty:
    df = pd.concat([df.drop(columns=['document']), document_df], axis=1)
if not query_df.empty:
    df = pd.concat([df.drop(columns=['query']), query_df], axis=1)

df_4o_mini_woC = df
import re
import pandas

def parse_grading_info(grading_text):
    # Extract category
    category_match = re.search(r'## (.+?)\n', grading_text)
    category = category_match.group(1).strip() if category_match else None

    # Extract rating
    rating_match = re.search(r'\* rating: (.+?)\n', grading_text)
    rating = rating_match.group(1).strip() if rating_match else None

    # Extract justification
    justification_match = re.search(r'\* justification: (.+?)(\n\*|\Z)', grading_text, re.S)
    justification = justification_match.group(1).strip() if justification_match else None

    return pd.Series([category, rating, justification])

# Apply the parsing function to the 'grading' column
df_4o_mini_woC[['category', 'rating', 'justification']] = df_4o_mini_woC['grading'].apply(parse_grading_info)
df_4o_mini_woC['4o_mini_woc_rating'] = df_4o_mini_woC['rating']
df_4o_mini_woC['4o_mini_woc_justification'] = df_4o_mini_woC['justification']

df_4o_mini_woC['4o_mini_woc_rating'] = pd.to_numeric(df_4o_mini_woC['4o_mini_woc_rating'], errors='coerce')
df_4o_mini_woC_mean = df_4o_mini_woC.groupby('query')['4o_mini_woc_rating'].agg(mean_4o_mini_woc_rating='mean', std_dev_4o_mini_woc='std').reset_index()
df_4o_mini_woC_mean
# Out:
# Total records loaded: 423
#                                                                                                                                                  query  \
# 0                                                                                                                   Evan Gershkovich prisoner exchange
# 1                                                                             How did Yusuf Dikec win a silver medal in shooting at the 2024 Olympics?
# 2                                                            I am going to Big Sky this weekend. What should I look into doing that is really popular?
# 3                                                                                                    Is Amazon stock a good buy after recent sell-off?
# 4                                                                                                                                        Summer movies
# 5                                                                                                         Things to do with mom in boston this weekend
# 6   What would be a reasonable cost estimate for API access to GPT 4o and Claude 3.5 Sonnet to create a few hundred outputs of 1 page length per month
# 7                                                                                                           Why are people criticizing Jonathan Owens?
# 8                                                                                                                                                 amzn
# 9                                                                                                                                         android docs
# 10                                                                                                                                 boutique pet stores
# 11                                                                                                              closest electric car charging stations
# 12                                                                                                               list of russian revolution characters
# 13                                                                                                                     mark zuckberg's childrens names
# 14                                                                                      melatonin dose is 3 mg or 6 mg a proper dose for an adult male
# 15                                                                                                                                           speedtest
# 16                                                                                                                   upcoming Planet of the Apes movie
# 17                                                                                         what is the latest update about US election, is trump quit?
# 18                                                                                                      who were some notable angel investors in wish
# 19                                                                                                                                              wordle
#
#     mean_4o_mini_woc_rating  std_dev_4o_mini_woc
# 0                  3.304348             2.382413
# 1                  5.058824             1.951621
# 2                  4.681818             1.886957
# 3                  4.222222             1.926764
# 4                  5.322581             1.469401
# 5                  2.681818             0.716231
# 6                  4.714286             1.270545
# 7                  3.888889             2.348689
# 8                  3.448276             1.638514
# 9                  3.307692             1.086986
# 10                 1.650000             0.587143
# 11                 1.937500             0.997914
# 12                 5.111111             1.476309
# 13                 3.047619             2.438774
# 14                 4.473684             1.743828
# 15                 5.058824             1.477777
# 16                 4.714286             2.163636
# 17                 3.739130             0.864312
# 18                 3.000000             1.383128
# 19                 4.600000             1.956674

# %%
## Importing gpt-4o-mini with context

import pandas as pd
import json
import blobfile as bf

# Use the local file path
file_path = "/tmp/dump_feather_results/graded_search_result_groups_dump_Rel_SamplewC_wC.jsonl"

# Initialize an empty list to collect all the records
records = []

# Read the JSONL file line by line and parse each line as JSON
try:
    with open(file_path, 'r') as f:
        for i, line in enumerate(f):
            try:
                # Load each line as a JSON object
                record = json.loads(line)
                records.append(record)
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON on line {i + 1}: {e}")
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")

# Print the number of records loaded
print(f"Total records loaded: {len(records)}")

# Convert the list of records to a DataFrame
df = pd.DataFrame(records)


# Function to parse nested JSON strings
def parse_nested_json(json_obj):
    if isinstance(json_obj, str):
        try:
            return json.loads(json_obj)
        except (json.JSONDecodeError, TypeError):
            return json_obj
    return json_obj

# Apply parsing to the 'document' and 'query' columns if they are in string format
if 'document' in df.columns:
    df['document'] = df['document'].apply(parse_nested_json)
if 'query' in df.columns:
    df['query'] = df['query'].apply(parse_nested_json)

# Further flatten the nested dictionaries if needed
document_df = pd.json_normalize(df['document']) if 'document' in df.columns else pd.DataFrame()
query_df = pd.json_normalize(df['query']) if 'query' in df.columns else pd.DataFrame()

# Combine the DataFrame with the parsed 'document' and 'query' columns
if not document_df.empty:
    df = pd.concat([df.drop(columns=['document']), document_df], axis=1)
if not query_df.empty:
    df = pd.concat([df.drop(columns=['query']), query_df], axis=1)

# Display the first few rows of the consolidated DataFrame
print("Consolidated DataFrame structure:")
df_4o_mini_wC = df

import re
import pandas

def parse_grading_info(grading_text):
    # Extract category
    category_match = re.search(r'## (.+?)\n', grading_text)
    category = category_match.group(1).strip() if category_match else None

    # Extract rating
    rating_match = re.search(r'\* rating: (.+?)\n', grading_text)
    rating = rating_match.group(1).strip() if rating_match else None

    # Extract justification
    justification_match = re.search(r'\* justification: (.+?)(\n\*|\Z)', grading_text, re.S)
    justification = justification_match.group(1).strip() if justification_match else None

    return pd.Series([category, rating, justification])

# Apply the parsing function to the 'grading' column
df_4o_mini_wC[['category', 'rating', 'justification']] = df_4o_mini_wC['grading'].apply(parse_grading_info)

df_4o_mini_wC['4o_mini_wc_rating'] = df_4o_mini_wC['rating']
df_4o_mini_wC['4o_mini_wc_justification'] = df_4o_mini_wC['justification']

df_4o_mini_wC['4o_mini_wc_rating'] = pd.to_numeric(df_4o_mini_wC['4o_mini_wc_rating'], errors='coerce')
df_4o_mini_mean = df_4o_mini_wC.groupby('query')['4o_mini_wc_rating'].agg(mean_4o_mini_wc_rating='mean', std_dev_4o_mini_wc='std').reset_index()
df_4o_mini_mean
# Out:
# Total records loaded: 423
# Consolidated DataFrame structure:
#                                                                                                                                                  query  \
# 0                                                                                                                   Evan Gershkovich prisoner exchange
# 1                                                                             How did Yusuf Dikec win a silver medal in shooting at the 2024 Olympics?
# 2                                                            I am going to Big Sky this weekend. What should I look into doing that is really popular?
# 3                                                                                                    Is Amazon stock a good buy after recent sell-off?
# 4                                                                                                                                        Summer movies
# 5                                                                                                         Things to do with mom in boston this weekend
# 6   What would be a reasonable cost estimate for API access to GPT 4o and Claude 3.5 Sonnet to create a few hundred outputs of 1 page length per month
# 7                                                                                                           Why are people criticizing Jonathan Owens?
# 8                                                                                                                                                 amzn
# 9                                                                                                                                         android docs
# 10                                                                                                                                 boutique pet stores
# 11                                                                                                              closest electric car charging stations
# 12                                                                                                               list of russian revolution characters
# 13                                                                                                                     mark zuckberg's childrens names
# 14                                                                                      melatonin dose is 3 mg or 6 mg a proper dose for an adult male
# 15                                                                                                                                           speedtest
# 16                                                                                                                   upcoming Planet of the Apes movie
# 17                                                                                         what is the latest update about US election, is trump quit?
# 18                                                                                                      who were some notable angel investors in wish
# 19                                                                                                                                              wordle
#
#     mean_4o_mini_wc_rating  std_dev_4o_mini_wc
# 0                 6.173913            0.834058
# 1                 5.588235            0.939336
# 2                 6.136364            0.940894
# 3                 5.111111            1.778595
# 4                 5.612903            1.054433
# 5                 3.272727            0.827032
# 6                 4.904762            1.445848
# 7                 5.833333            0.514496
# 8                 5.137931            1.641518
# 9                 4.269231            1.185165
# 10                1.500000            0.512989
# 11                2.187500            1.470544
# 12                4.259259            1.852080
# 13                3.857143            1.878449
# 14                5.894737            0.315302
# 15                5.000000            1.414214
# 16                5.714286            0.825420
# 17                4.173913            0.886883
# 18                3.500000            1.215838
# 19                5.200000            1.612452

# %%
## Importing gpt-4o-mini with context

import pandas as pd
import json
import blobfile as bf

# Use the local file path
file_path = "/tmp/dump_feather_results/graded_search_result_groups_dump_Rel_SamplewC_cb_wC.jsonl"

# Initialize an empty list to collect all the records
records = []

# Read the JSONL file line by line and parse each line as JSON
try:
    with open(file_path, 'r') as f:
        for i, line in enumerate(f):
            try:
                # Load each line as a JSON object
                record = json.loads(line)
                records.append(record)
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON on line {i + 1}: {e}")
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")

# Print the number of records loaded
print(f"Total records loaded: {len(records)}")

# Convert the list of records to a DataFrame
df = pd.DataFrame(records)


# Function to parse nested JSON strings
def parse_nested_json(json_obj):
    if isinstance(json_obj, str):
        try:
            return json.loads(json_obj)
        except (json.JSONDecodeError, TypeError):
            return json_obj
    return json_obj

# Apply parsing to the 'document' and 'query' columns if they are in string format
if 'document' in df.columns:
    df['document'] = df['document'].apply(parse_nested_json)
if 'query' in df.columns:
    df['query'] = df['query'].apply(parse_nested_json)

# Further flatten the nested dictionaries if needed
document_df = pd.json_normalize(df['document']) if 'document' in df.columns else pd.DataFrame()
query_df = pd.json_normalize(df['query']) if 'query' in df.columns else pd.DataFrame()

# Combine the DataFrame with the parsed 'document' and 'query' columns
if not document_df.empty:
    df = pd.concat([df.drop(columns=['document']), document_df], axis=1)
if not query_df.empty:
    df = pd.concat([df.drop(columns=['query']), query_df], axis=1)

# Display the first few rows of the consolidated DataFrame
print("Consolidated DataFrame structure:")
df_o3_mini_woC = df

import re
import pandas

def parse_grading_info(grading_text):
    # Extract category
    category_match = re.search(r'## (.+?)\n', grading_text)
    category = category_match.group(1).strip() if category_match else None

    # Extract rating
    rating_match = re.search(r'\* rating: (.+?)\n', grading_text)
    rating = rating_match.group(1).strip() if rating_match else None

    # Extract justification
    justification_match = re.search(r'\* justification: (.+?)(\n\*|\Z)', grading_text, re.S)
    justification = justification_match.group(1).strip() if justification_match else None

    return pd.Series([category, rating, justification])

# Apply the parsing function to the 'grading' column
df_o3_mini_woC[['category', 'rating', 'justification']] = df_o3_mini_woC['grading'].apply(parse_grading_info)

df_o3_mini_woC['o3_mini_woC_rating'] = df_o3_mini_woC['rating']
df_o3_mini_woC['o3_mini_woC_justification'] = df_o3_mini_woC['justification']

df_o3_mini_woC['o3_mini_woC_rating'] = pd.to_numeric(df_o3_mini_woC['o3_mini_woC_rating'], errors='coerce')
df_o3_mini_woC_mean = df_o3_mini_woC.groupby('query')['o3_mini_woC_rating'].agg(mean_o3_mini_woC_rating='mean', std_dev_o3_mini_woC='std').reset_index()
df_o3_mini_woC_mean
# Out:
# Total records loaded: 423
# Consolidated DataFrame structure:
#                                                                                                                                                  query  \
# 0                                                                                                                   Evan Gershkovich prisoner exchange
# 1                                                                             How did Yusuf Dikec win a silver medal in shooting at the 2024 Olympics?
# 2                                                            I am going to Big Sky this weekend. What should I look into doing that is really popular?
# 3                                                                                                    Is Amazon stock a good buy after recent sell-off?
# 4                                                                                                                                        Summer movies
# 5                                                                                                         Things to do with mom in boston this weekend
# 6   What would be a reasonable cost estimate for API access to GPT 4o and Claude 3.5 Sonnet to create a few hundred outputs of 1 page length per month
# 7                                                                                                           Why are people criticizing Jonathan Owens?
# 8                                                                                                                                                 amzn
# 9                                                                                                                                         android docs
# 10                                                                                                                                 boutique pet stores
# 11                                                                                                              closest electric car charging stations
# 12                                                                                                               list of russian revolution characters
# 13                                                                                                                     mark zuckberg's childrens names
# 14                                                                                      melatonin dose is 3 mg or 6 mg a proper dose for an adult male
# 15                                                                                                                                           speedtest
# 16                                                                                                                   upcoming Planet of the Apes movie
# 17                                                                                         what is the latest update about US election, is trump quit?
# 18                                                                                                      who were some notable angel investors in wish
# 19                                                                                                                                              wordle
#
#     mean_o3_mini_woC_rating  std_dev_o3_mini_woC
# 0                  6.227273             1.109776
# 1                  5.500000             1.825742
# 2                  6.181818             0.732664
# 3                  3.500000             1.465285
# 4                  6.290323             1.006431
# 5                  3.047619             1.071270
# 6                  2.857143             1.236354
# 7                  4.277778             2.492472
# 8                  6.750000             0.518188
# 9                  3.166667             0.564660
# 10                 2.210526             0.630604
# 11                 2.625000             1.454877
# 12                 5.629630             1.821837
# 13                 4.476190             1.833550
# 14                 5.529412             1.007326
# 15                 5.312500             1.195478
# 16                 5.500000             0.797724
# 17                 1.772727             0.528413
# 18                 1.416667             0.717282
# 19                 6.800000             0.414039

# %% [markdown]
# # **Importing the human eval data set**

# %%
# Import necessary libraries
import nest_asyncio
import asyncio
import pandas as pd
import numpy as np
import csv
import uuid
import blobfile as bf

from pydantic import BaseModel, Field
from tenacity import retry, retry_if_exception_type, stop_after_attempt, wait_random_exponential

from feather_api_client.client import FeatherAPIError, FeatherClient, FeatherTier
from feather_api_client.search_types import (
    FilterValue,
    Operator,
    SearchType,
    StringListFilter,
    TaskFilter,
)
from feather_api_client.types import (
    FeatherRegiment,
    FeatherRegimentSourceInfo,
    FeatherRegimentType,
    FeatherRegimentVersion,
    FeatherTask,
    FeatherTaskBatchQuality,
    FeatherTaskStatus,
    FeatherUser,
    SearchFeatherTaskBatchesParams,
    SearchFeatherTasksV2Request,
    SearchRegimentsParams,
    SearchRegimentsResponse,
)
from harmony_components.directload.condor_query import CondorQuery
from harmony_components.directload.snapshots import SnapshotNameType
from harmony_components.directload.types import DatasetSplit
from oaicommon import oai_itertools

# Apply nest_asyncio to allow nested asyncio calls in Jupyter Notebook
nest_asyncio.apply()

# Define the asynchronous function to process tasks
async def process_tasks():
    with bf.BlobFile('az://oaidatasets2/chatgpt/sonic/x/npancha/filt.csv', 'r') as f:
        r = list(csv.reader(f))
    qts = {k.strip().lower(): float(v) for _, k, v in r[1:]}
    c = FeatherClient("regiment_client", instance=FeatherTier("prod"))
    try:
        tb = await c.get_task_batch(uuid.UUID('685f9d0e-1b03-442e-b09d-b3339e2a4340'))
    except Exception as e:
        print(f"Exception occurred while fetching task batch: {e}")
        return
    if tb is None:
        print("Error: Task batch not found or is empty.")
        return
    if not tb.task_ids:
        print("Error: No task IDs found in the batch.")
        return

    async def debug_get_task(task_id):
        task = await c.get_task(task_id)
        return task

    tasks = await asyncio.gather(*map(debug_get_task, tb.task_ids))
    rtgs = [
        {
            'a': v['scorecard-a'],
            'b': v['scorecard-b'],
            's': qts[t.metadata['query'].strip().lower()],
            'query_text': t.metadata['query']  # Add query text here
        }
        for t in tasks
        if len(v := next(iter(t.form_content.values()))['search-completion-rating']) == 2
    ]

    df_human_eval = pd.DataFrame.from_records(rtgs)
    return df_human_eval

    '''
    print('Found', len(rtgs), 'ratings')
    print('Found', sum(t.reviews is not None for t in tasks), 'reviews')

    print('Below is the analysis for threshold 0.457')
    df = pd.DataFrame.from_records(rtgs).query('s >= 0.457')
    print('Rating distribution')
    print(pd.DataFrame(df['a'].value_counts()).join(pd.DataFrame(df['b'].value_counts()), lsuffix='_a', rsuffix='_b'))
    print('Rating a - rating b distribution')
    print((df.a - df.b).apply(lambda x: np.clip(x, -2, 2)).value_counts().sort_index())
    print(((df.a - df.b) < 0).mean())
    print(((df.a - df.b) > 0).mean())
    print(df[(df['a']-df['b'])==-2]['query_text'])

    print('Below is the analysis for threshold 0.47')
    df = pd.DataFrame.from_records(rtgs).query('s >= 0.47')
    print('Rating distribution')
    print(pd.DataFrame(df['a'].value_counts()).join(pd.DataFrame(df['b'].value_counts()), lsuffix='_a', rsuffix='_b'))
    print('Rating a - rating b distribution')
    print((df.a - df.b).apply(lambda x: np.clip(x, -2, 2)).value_counts().sort_index())
    print(((df.a - df.b) < 0).mean())
    print(((df.a - df.b) > 0).mean())
    print(df[(df['a']-df['b'])==-2]['query_text'])

    return df

'''


# Run the async function in Jupyter Notebook
df_human_eval = await process_tasks()

# %%
df_human_eval['he_oai_index'] = df_human_eval['a']
df_human_eval['he_serp'] = df_human_eval['b']
df_human_eval['query'] = df_human_eval['query_text']
def rescale_1_to_5_to_1_to_7(rating):
    return ((rating - 1) / (5 - 1)) * (7 - 1) + 1

# Apply the rescaling function to the 'rating' column
df_human_eval['he_oai_index'] = df_human_eval['he_oai_index'].apply(rescale_1_to_5_to_1_to_7)
df_human_eval['he_serp'] = df_human_eval['he_serp'].apply(rescale_1_to_5_to_1_to_7)
df_human_eval.dtypes
# Out:
# a                 int64
# b                 int64
# s               float64
# query_text       object
# he_oai_index    float64
# he_serp         float64
# query            object
# dtype: object

# %%
## Join all the dataframes

df_final = df_human_eval[['query','he_oai_index','he_serp']].merge(df_4o_mini_woC_mean,on='query').merge(df_4o_mini_mean,on='query').merge(df_o3_mini_woC_mean,on='query')
df_final.sort_values('he_oai_index')
# Out:
#                                                                                                                                                  query  \
# 18                                                                                                              closest electric car charging stations
# 16                                                                                                                                 boutique pet stores
# 2                                                                                                    Is Amazon stock a good buy after recent sell-off?
# 15                                                                                                                   upcoming Planet of the Apes movie
# 6                                                                                          what is the latest update about US election, is trump quit?
# 11                                                                                                      who were some notable angel investors in wish
# 14                                                           I am going to Big Sky this weekend. What should I look into doing that is really popular?
# 12  What would be a reasonable cost estimate for API access to GPT 4o and Claude 3.5 Sonnet to create a few hundred outputs of 1 page length per month
# 17                                                                            How did Yusuf Dikec win a silver medal in shooting at the 2024 Olympics?
# 0                                                                                                         Things to do with mom in boston this weekend
# 10                                                                                                                  Evan Gershkovich prisoner exchange
# 7                                                                                                           Why are people criticizing Jonathan Owens?
# 5                                                                                                                list of russian revolution characters
# 13                                                                                                                                                amzn
# 4                                                                                                                      mark zuckberg's childrens names
# 3                                                                                                                                        Summer movies
# 1                                                                                                                                               wordle
# 8                                                                                                                                         android docs
# 9                                                                                       melatonin dose is 3 mg or 6 mg a proper dose for an adult male
#
#     he_oai_index  he_serp  mean_4o_mini_woc_rating  std_dev_4o_mini_woc  \
# 18           4.0      5.5                 1.937500             0.997914
# 16           4.0      5.5                 1.650000             0.587143
# 2            4.0      4.0                 4.222222             1.926764
# 15           4.0      5.5                 4.714286             2.163636
# 6            4.0      5.5                 3.739130             0.864312
# 11           4.0      4.0                 3.000000             1.383128
# 14           5.5      7.0                 4.681818             1.886957
# 12           5.5      4.0                 4.714286             1.270545
# 17           5.5      5.5                 5.058824             1.951621
# 0            5.5      5.5                 2.681818             0.716231
# 10           7.0      5.5                 3.304348             2.382413
# 7            7.0      7.0                 3.888889             2.348689
# 5            7.0      5.5                 5.111111             1.476309
# 13           7.0      7.0                 3.448276             1.638514
# 4            7.0      7.0                 3.047619             2.438774
# 3            7.0      5.5                 5.322581             1.469401
# 1            7.0      5.5                 4.600000             1.956674
# 8            7.0      5.5                 3.307692             1.086986
# 9            7.0      5.5                 4.473684             1.743828
#
#     mean_4o_mini_wc_rating  std_dev_4o_mini_wc  mean_o3_mini_woC_rating  \
# 18                2.187500            1.470544                 2.625000
# 16                1.500000            0.512989                 2.210526
# 2                 5.111111            1.778595                 3.500000
# 15                5.714286            0.825420                 5.500000
# 6                 4.173913            0.886883                 1.772727
# 11                3.500000            1.215838                 1.416667
# 14                6.136364            0.940894                 6.181818
# 12                4.904762            1.445848                 2.857143
# 17                5.588235            0.939336                 5.500000
# 0                 3.272727            0.827032                 3.047619
# 10                6.173913            0.834058                 6.227273
# 7                 5.833333            0.514496                 4.277778
# 5                 4.259259            1.852080                 5.629630
# 13                5.137931            1.641518                 6.750000
# 4                 3.857143            1.878449                 4.476190
# 3                 5.612903            1.054433                 6.290323
# 1                 5.200000            1.612452                 6.800000
# 8                 4.269231            1.185165                 3.166667
# 9                 5.894737            0.315302                 5.529412
#
#     std_dev_o3_mini_woC
# 18             1.454877
# 16             0.630604
# 2              1.465285
# 15             0.797724
# 6              0.528413
# 11             0.717282
# 14             0.732664
# 12             1.236354
# 17             1.825742
# 0              1.071270
# 10             1.109776
# 7              2.492472
# 5              1.821837
# 13             0.518188
# 4              1.833550
# 3              1.006431
# 1              0.414039
# 8              0.564660
# 9              1.007326

# %%
## Within variance as a % of mean for each model type

print('4o_mini_woc=', np.mean(df_final['std_dev_4o_mini_woc']**2/df_final['mean_4o_mini_woc_rating']),
                              '4o_mini_wc=', np.mean(df_final['std_dev_4o_mini_wc']**2/df_final['mean_4o_mini_wc_rating']),
                              'o3_mini_woC=',np.mean(df_final['std_dev_o3_mini_woC']**2/df_final['mean_o3_mini_woC_rating']))
# Out:
# 4o_mini_woc= 0.7393381353513392 4o_mini_wc= 0.36299853881638827 o3_mini_woC= 0.38639004200087135

# %%
## Between variance i.e. variance of means

print('4o_mini_woc=', np.std(df_final['mean_4o_mini_woc_rating'])**2/np.mean(df_final['mean_4o_mini_woc_rating']),
                              '4o_mini_wc=', np.std(df_final['mean_4o_mini_wc_rating'])**2/np.mean(df_final['mean_4o_mini_wc_rating']),
                              'o3_mini_woC=',np.std(df_final['mean_o3_mini_woC_rating'])**2/np.mean(df_final['mean_o3_mini_woC_rating']))
# Out:
# 4o_mini_woc= 0.281034183853949 4o_mini_wc= 0.3577398861613026 o3_mini_woC= 0.6791445185123794

# %%
query_string = 'what is the latest update about US election, is trump quit?'
#query_string = 'What would be a reasonable cost estimate for API access to GPT 4o and Claude 3.5 Sonnet to create a few hundred outputs of 1 page length per month'
#query_string = 'android docs'
#query_string = 'closest electric car charging stations'

filtered_df = df_o3_mini_woC[['query', 'create_timestamp','o3_mini_woC_rating', 'o3_mini_woC_justification', 'document.url', 'document.title', 'document.content', 'document.pub_date']].query('query == @query_string')

filtered_df
# Out:
#                                                           query  \
# 66  what is the latest update about US election, is trump quit?
# 67  what is the latest update about US election, is trump quit?
# 68  what is the latest update about US election, is trump quit?
# 69  what is the latest update about US election, is trump quit?
# 70  what is the latest update about US election, is trump quit?
# 71  what is the latest update about US election, is trump quit?
# 72  what is the latest update about US election, is trump quit?
# 73  what is the latest update about US election, is trump quit?
# 74  what is the latest update about US election, is trump quit?
# 75  what is the latest update about US election, is trump quit?
# 76  what is the latest update about US election, is trump quit?
# 77  what is the latest update about US election, is trump quit?
# 78  what is the latest update about US election, is trump quit?
# 79  what is the latest update about US election, is trump quit?
# 80  what is the latest update about US election, is trump quit?
# 81  what is the latest update about US election, is trump quit?
# 82  what is the latest update about US election, is trump quit?
# 83  what is the latest update about US election, is trump quit?
# 84  what is the latest update about US election, is trump quit?
# 85  what is the latest update about US election, is trump quit?
# 86  what is the latest update about US election, is trump quit?
# 87  what is the latest update about US election, is trump quit?
# 88  what is the latest update about US election, is trump quit?
#
#                     create_timestamp  o3_mini_woC_rating  \
# 66  2025-01-07T18:33:54.254126-05:00                 2.0
# 67  2025-01-07T18:33:54.254126-05:00                 1.0
# 68  2025-01-07T18:33:54.254126-05:00                 2.0
# 69  2025-01-07T18:33:54.254126-05:00                 2.0
# 70  2025-01-07T18:33:54.254126-05:00                 2.0
# 71  2025-01-07T18:33:54.254126-05:00                 2.0
# 72  2025-01-07T18:33:54.254126-05:00                 2.0
# 73  2025-01-07T18:33:54.254126-05:00                 NaN
# 74  2025-01-07T18:33:54.254126-05:00                 2.0
# 75  2025-01-07T18:33:54.254126-05:00                 2.0
# 76  2025-01-07T18:33:54.254126-05:00                 1.0
# 77  2025-01-07T18:33:54.254126-05:00                 2.0
# 78  2025-01-07T18:33:54.254126-05:00                 2.0
# 79  2025-01-07T18:33:54.254126-05:00                 2.0
# 80  2025-01-07T18:33:54.254126-05:00                 2.0
# 81  2025-01-07T18:33:54.254126-05:00                 1.0
# 82  2025-01-07T18:33:54.254126-05:00                 1.0
# 83  2025-01-07T18:33:54.254126-05:00                 2.0
# 84  2025-01-07T18:33:54.254126-05:00                 1.0
# 85  2025-01-07T18:33:54.254126-05:00                 2.0
# 86  2025-01-07T18:33:54.254126-05:00                 1.0
# 87  2025-01-07T18:33:54.254126-05:00                 3.0
# 88  2025-01-07T18:33:54.254126-05:00                 2.0
#
#                                                                                                                                       o3_mini_woC_justification  \
# 66                                     The article discusses Biden dropping out in 2024, not the latest 2025 US election update or Trump quitting specifically.
# 67                            The document discusses GOP reaction to Biden dropping out, not latest US election update or Trump quitting, so it's not relevant.
# 68                                 The article discusses Biden dropping out and Trump's reaction, not the latest US election update or Trump quitting the race.
# 69                        The article doesn’t address the user’s query about Trump quitting and latest election update, focusing instead on Biden dropping out.
# 70              The document discusses Biden dropping out and GOP reactions, not the latest US election update about Trump quitting, so it's largely off‑topic.
# 71                         The document discusses Biden dropping out and GOP reactions, not latest US election update or whether Trump quit, so it's off topic.
# 72            The document discusses Biden dropping out and GOP reactions, not the latest US election update or whether Trump quit, so it's largely irrelevant.
# 73                                                                                                                                                         None
# 74                    The article discusses reactions to Biden dropping out, not the latest US election update about Trump quitting, so it's largely off topic.
# 75                      The document discusses Biden dropping out and GOP reactions, not the latest US election update about Trump quitting, so it's off-topic.
# 76                       The article discusses Biden dropping out in 2024 and reactions, not a 2025 US election update or Trump quitting, so it's not relevant.
# 77                The article discusses Biden dropping out and reactions, not the latest 2025 US election update or Trump quitting, so it's largely irrelevant.
# 78                              The article discusses Biden and GOP reactions, not latest US election update or whether Trump quit, so it's largely irrelevant.
# 79                        The article discusses Biden dropping out in mid‑2024, not a 2025 US election update or Trump quitting. It doesn't match query intent.
# 80                  The article discusses Biden quitting 2024 race and Trump's reaction, not the latest 2025 election update or Trump quitting. It's off topic.
# 81                                     Content covers July 2024 Biden news, not the requested latest 2025 US election update or Trump's status. It's off topic.
# 82                                        The document doesn’t address the query about Trump quitting or latest 2025 election update and is largely irrelevant.
# 83                           Content discusses Biden stepping down in 2024, not the queried latest US election update about Trump quitting, so it’s off target.
# 84                               Document discusses Biden quitting in 2024, not latest US election update about Trump quitting in Jan 2025 – it's not relevant.
# 85                       The document discusses July 2024 Biden news, not the latest 2025 US election update or whether Trump quit, so it's largely irrelevant.
# 86                      The document discusses Biden dropping out and Trump’s comments, not about Trump quitting or latest 2025 election update, so irrelevant.
# 87  The article discusses Trump’s future election plans but isn’t a direct latest update for January 2025 or clearly answers if he quit; only somewhat related.
# 88                  The article is about the 2020 election and Trump leaving White House, not a latest 2025 update or quitting context. It's mostly irrelevant.
#
#                                                                                                            document.url  \
# 66                                       https://www.fox5atlanta.com/news/donald-trump-responds-biden-dropping-out-race
# 67                        https://www.cbsnews.com/news/republican-lawmakers-react-biden-dropping-out-presidential-race/
#
missing_rate = df_o3_mini_woC.isnull().sum() * 100 / len(df_o3_mini_woC)
missing_rate
# Out:
# grading                                0.000000
# context                                0.000000
# document.url                           0.000000
# document.title                         0.000000
# document.content                       0.000000
# document.pub_date                    100.000000
# query                                  0.000000
# create_timestamp                       0.000000
# orig_query                           100.000000
# user_metadata.time_zone              100.000000
# user_metadata.user_locale            100.000000
# user_metadata.cf_connecting_ip       100.000000
# user_metadata.user_country             0.000000
# user_metadata.user_region              0.000000
# user_metadata.user_region_code       100.000000
# user_metadata.ip_city                  0.000000
# user_metadata.latitude               100.000000
# user_metadata.longitude              100.000000
# user_metadata.locationAccuracy       100.000000
# user_metadata.is_precise_location    100.000000
# user_metadata.plan_type              100.000000
# category                               3.073286
# rating                                 3.073286
# justification                          3.073286
# o3_mini_woC_rating                     3.073286
# o3_mini_woC_justification              3.073286
# dtype: float64

# %%
query_string = 'what is the latest update about US election, is trump quit?'
#query_string = 'What would be a reasonable cost estimate for API access to GPT 4o and Claude 3.5 Sonnet to create a few hundred outputs of 1 page length per month'
#query_string = 'android docs'

filtered_df = df_4o_mini_woC[['query', 'create_timestamp','4o_mini_woc_rating', '4o_mini_woc_justification', 'document.url', 'document.title','document.content', 'document.pub_date']].query('query == @query_string')

filtered_df
# Out:
#                                                           query  \
# 66  what is the latest update about US election, is trump quit?
# 67  what is the latest update about US election, is trump quit?
# 68  what is the latest update about US election, is trump quit?
# 69  what is the latest update about US election, is trump quit?
# 70  what is the latest update about US election, is trump quit?
# 71  what is the latest update about US election, is trump quit?
# 72  what is the latest update about US election, is trump quit?
# 73  what is the latest update about US election, is trump quit?
# 74  what is the latest update about US election, is trump quit?
# 75  what is the latest update about US election, is trump quit?
# 76  what is the latest update about US election, is trump quit?
# 77  what is the latest update about US election, is trump quit?
# 78  what is the latest update about US election, is trump quit?
# 79  what is the latest update about US election, is trump quit?
# 80  what is the latest update about US election, is trump quit?
# 81  what is the latest update about US election, is trump quit?
# 82  what is the latest update about US election, is trump quit?
# 83  what is the latest update about US election, is trump quit?
# 84  what is the latest update about US election, is trump quit?
# 85  what is the latest update about US election, is trump quit?
# 86  what is the latest update about US election, is trump quit?
# 87  what is the latest update about US election, is trump quit?
# 88  what is the latest update about US election, is trump quit?
#
#                     create_timestamp  4o_mini_woc_rating  \
# 66  2025-01-07T18:33:54.254126-05:00                   4
# 67  2025-01-07T18:33:54.254126-05:00                   3
# 68  2025-01-07T18:33:54.254126-05:00                   5
# 69  2025-01-07T18:33:54.254126-05:00                   4
# 70  2025-01-07T18:33:54.254126-05:00                   3
# 71  2025-01-07T18:33:54.254126-05:00                   3
# 72  2025-01-07T18:33:54.254126-05:00                   4
# 73  2025-01-07T18:33:54.254126-05:00                   3
# 74  2025-01-07T18:33:54.254126-05:00                   4
# 75  2025-01-07T18:33:54.254126-05:00                   4
# 76  2025-01-07T18:33:54.254126-05:00                   3
# 77  2025-01-07T18:33:54.254126-05:00                   3
# 78  2025-01-07T18:33:54.254126-05:00                   3
# 79  2025-01-07T18:33:54.254126-05:00                   4
# 80  2025-01-07T18:33:54.254126-05:00                   5
# 81  2025-01-07T18:33:54.254126-05:00                   4
# 82  2025-01-07T18:33:54.254126-05:00                   3
# 83  2025-01-07T18:33:54.254126-05:00                   3
# 84  2025-01-07T18:33:54.254126-05:00                   3
# 85  2025-01-07T18:33:54.254126-05:00                   3
# 86  2025-01-07T18:33:54.254126-05:00                   5
# 87  2025-01-07T18:33:54.254126-05:00                   6
# 88  2025-01-07T18:33:54.254126-05:00                   4
#
#                                                                                                                                                                                                                                4o_mini_woc_justification  \
# 66                                                                                                                                                 The document discusses Biden's withdrawal from the race but does not address Trump's status directly.
# 67                                                                                                                                           The document discusses Biden's withdrawal but does not address Trump's status or the user's query directly.
# 68                                                                                                    The document discusses Trump's reaction to Biden dropping out, partially addressing the query about updates on the US election and Trump's status.
# 69                                                                                                                              The document discusses Biden's withdrawal but lacks direct information on Trump's status or the latest election updates.
# 70                                                                                                                                           The document discusses Biden's withdrawal but does not address Trump's status or the user's query directly.
# 71                                                                                                                                           The document discusses Biden's withdrawal but does not address Trump's status or the user's query directly.
# 72                                                                                                                                The document discusses Biden's withdrawal but does not address Trump's status or the latest election updates directly.
# 73                                                                                                                                         The document discusses Biden's withdrawal but does not address Trump's status or the latest election updates.
# 74                                                                                                                                           The document discusses Biden's withdrawal but lacks direct information on Trump's status or latest updates.
# 75                                                                                                                                           The document discusses Biden's withdrawal but lacks direct information on Trump's status or latest updates.
# 76                                                                                                                                         The document discusses Biden's withdrawal but does not address Trump's status or the latest election updates.
# 77                                                                                                                                           The document discusses Biden's withdrawal but lacks direct information on Trump's status or latest updates.
# 78                                                                                                                                           The document discusses Biden's withdrawal but does not address Trump's status or the user's query directly.
# 79                                                                                                                                                 The document discusses Biden's withdrawal from the race but does not address Trump's status directly.
# 80  The document discusses Biden's withdrawal from the 2024 election, which is relevant to the query about the latest updates on the US election. However, it does not directly address whether Trump has quit, which is a key part of the user's query.
# 81                                                                                                                                            The document discusses Biden's withdrawal from the race but lacks direct information about Trump's status.
# 82                                                                                                                                        The document discusses Biden's exit but does not address Trump's status or the latest updates on the election.
# 83                                                                                                               The document discusses Biden's campaign status but does not address Trump's potential withdrawal or the latest updates on the election.
# 84                                                                                                                    The document discusses Biden's withdrawal from the race but does not address Trump's status or the latest updates on the election.
# 85                                                                                                                                         The document discusses Biden's withdrawal but does not address Trump's status or the latest election updates.
# 86                                                                                                The document discusses Trump's response to Biden's withdrawal, partially addressing the query about the latest US election updates and Trump's status.
# 87                                                                                                          The document directly addresses the query about Trump's potential withdrawal from the election, providing specific and relevant information.
# 88                                                                                                                    The document provides some relevant information about Trump's potential departure but lacks the latest updates as of January 2025.
#
#                                                                                                            document.url  \
# 66                                       https://www.fox5atlanta.com/news/donald-trump-responds-biden-dropping-out-race
# 67                        https://www.cbsnews.com/news/republican-lawmakers-react-biden-dropping-out-presidential-race/
# 68                        https://www.cbsnews.com/news/republican-lawmakers-react-biden-dropping-out-presidential-race/
# 69                        https://www.cbsnews.com/news/republican-lawmakers-react-biden-dropping-out-presidential-race/
# 70                        https://www.cbsnews.com/news/republican-lawmakers-react-biden-dropping-out-presidential-race/
# 71                        https://www.cbsnews.com/news/republican-lawmakers-react-biden-dropping-out-presidential-race/
# 72  https://www.cbsnews.com/news/republican-lawmakers-react-biden-dropping-out-presidential-race/?intcid=CNI-00-10aaa3a
# 73  https://www.cbsnews.com/news/republican-lawmakers-react-biden-dropping-out-presidential-race/?intcid=CNI-00-10aaa3a
# 74  https://www.cbsnews.com/news/republican-lawmakers-react-biden-dropping-out-presidential-race/?intcid=CNI-00-10aaa3a
# 75        https://www.cbsnews.com/news/republican-lawmakers-react-biden-dropping-out-presidential-race/